# %% [markdown]
# <a href="https://colab.research.google.com/github/chavan-sanika/NYC_Taxies/blob/main/Taxi_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Trip Outcomes**

# %% [markdown]
# ![Trip outcomes.PNG](data:image/png;base64,...)

# %% [markdown]
# **Revenue Analysis**

# %% [markdown]
# ![Revenue Analysis.PNG](data:image/png;base64,...)

# %% [markdown]
# **Location Insights**

# %% [markdown]
# ![Location insights.PNG](data:image/png;base64,...)
